# %%
import json
from collections import defaultdict

def load_json(filepath):
    with open(filepath, 'r') as f:
        return json.load(f)

def compare_extracted_criteria(gpt_data, ground_truth_data):
    results = []
    mismatch_counts = defaultdict(lambda: defaultdict(int))  # Track mismatches by section and key

    for gpt_trial, gt_trial in zip(gpt_data, ground_truth_data):
        gpt_criteria = gpt_trial.get("Extracted Criteria", {})
        gt_criteria = gt_trial.get("Extracted Criteria", {})

        for section in gpt_criteria:
            # Skip specific sections
            if section in ["text_relating_to_medical_history", "unused_text"]:
                continue

            gpt_section = gpt_criteria.get(section, {})
            gt_section = gt_criteria.get(section, {})

            for key, gt_value in gt_section.items():
                gpt_value = gpt_section.get(key, None)
                match = gt_value == gpt_value


                results.append({
                    "section": section,
                    "key": key,
                    "ground_truth": gt_value,
                    "gpt_extracted": gpt_value,
                    "match": match
                })

                # Increment mismatch count for the key in the section if there's a mismatch
                if not match:
                    mismatch_counts[section][key] += 1

    return results, mismatch_counts


def calculate_accuracy(results):
    total = len(results)
    matches = sum(1 for result in results if result["match"])
    return matches / total if total > 0 else 0


def main():
    gpt_file = "extracted_criteria_30.json"
    ground_truth_file = "ground_truth_30.json"

    # Load data
    gpt_data = load_json(gpt_file)
    ground_truth_data = load_json(ground_truth_file)

    # Compare criteria
    comparison_results, mismatch_counts = compare_extracted_criteria(gpt_data, ground_truth_data)

    accuracy = calculate_accuracy(comparison_results)
    print(f"Overall Accuracy: {accuracy:.2f}")

    mismatches = [r for r in comparison_results if not r["match"]]
    if mismatches:
        print("\nMismatched Entries:")
        for mismatch in mismatches:
            print(mismatch)

    print("\nMismatch Count by Section and Key:")
    for section, keys in mismatch_counts.items():
        print(f"Section: {section}")
        for key, count in keys.items():
            print(f"  {key}: {count} mismatches")

if __name__ == "__main__":
    main()
# Out:
# Overall Accuracy: 0.69
#
# Mismatched Entries:
# {'section': 'demographics_and_general_characteristics', 'key': 'signed_consent', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_locally_recurrent_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'signed_consent', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_locally_recurrent_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_metastases_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_locally_recurrent_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'months_of_life_expectancy', 'ground_truth': '12', 'gpt_extracted': 3, 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_metastases_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_locally_recurrent_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_heart_cardiovascular_function', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_brain_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_metastases', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_pregnancy_nursing', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_metastases_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_locally_recurrent_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'progress_after_previous_treatment', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_heart_cardiovascular_function', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'ecog_performance_status_upper_bound', 'ground_truth': 1, 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_central_nervous_system_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_locally_recurrent_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_renal_function', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_bone_marrow', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_liver_function', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_brain_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'minimum_age', 'ground_truth': 18, 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'maximum_age', 'ground_truth': '', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'months_of_life_expectancy', 'ground_truth': 3, 'gpt_extracted': 12, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'signed_consent', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_brain_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'months_of_life_expectancy', 'ground_truth': 4, 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_heart_cardiovascular_function', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'ast_alt_upper_bound_uln', 'ground_truth': 2.5, 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'bilirubin_upper_bound_uln', 'ground_truth': 3, 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'months_of_life_expectancy', 'ground_truth': 4, 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'no_concurrent_participation_in_other_clinical_trials', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_renal_function', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_heart_cardiovascular_function', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'peripheral_neuropathy_grade_upper_bound', 'ground_truth': 1, 'gpt_extracted': 2, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'signed_consent', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'no_concurrent_participation_in_other_clinical_trials', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_renal_function', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_heart_cardiovascular_function', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'bilirubin_upper_bound_uln', 'ground_truth': 2, 'gpt_extracted': 1.5, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_brain_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'minimum_age', 'ground_truth': 18, 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_renal_function', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_liver_function', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_heart_cardiovascular_function', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_lung_function', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'hgb_level_lower_bound_10_9_l', 'ground_truth': 9, 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_brain_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_locally_recurrent_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_heart_cardiovascular_function', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_brain_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'no_concurrent_participation_in_other_clinical_trials', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_metastases_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_locally_recurrent_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'progress_after_previous_treatment', 'ground_truth': '', 'gpt_extracted': 'Yes', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'ast_alt_upper_bound_uln', 'ground_truth': 3, 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'lvef_lower_bound_percent', 'ground_truth': 50, 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_brain_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_locally_recurrent_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'her2_status', 'ground_truth': 'Positive', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_central_nervous_system_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'months_of_life_expectancy', 'ground_truth': 3, 'gpt_extracted': 12, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'ast_alt_upper_bound_uln', 'ground_truth': 2.5, 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'swallow_ability', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'minimum_age', 'ground_truth': 18, 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'months_of_life_expectancy', 'ground_truth': 3, 'gpt_extracted': 12, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_brain_metastases', 'ground_truth': 'No', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'peripheral_neuropathy_grade_upper_bound', 'ground_truth': 1, 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_positive_hiv_status', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'months_of_life_expectancy', 'ground_truth': '', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'signed_consent', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_metastases_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_locally_recurrent_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_renal_function', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_bone_marrow', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_liver_function', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_central_nervous_system_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'follow_up_agreement', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'signed_consent', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'no_concurrent_participation_in_other_clinical_trials', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'disease_characteristics', 'key': 'confirmed_locally_recurrent_breast_cancer', 'ground_truth': 'Yes', 'gpt_extracted': 'Inferred', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'anc_level_lower_bound_10_9_l', 'ground_truth': 1.5, 'gpt_extracted': 1500, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_brain_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': '', 'match': False}
# {'section': 'demographics_and_general_characteristics', 'key': 'protocol_compliance', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_liver_function', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'sufficient_lung_function', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'no_central_nervous_system_metastases', 'ground_truth': 'Yes', 'gpt_extracted': 'No', 'match': False}
# {'section': 'health_and_organ_function', 'key': 'peripheral_neuropathy_grade_upper_bound', 'ground_truth': 1, 'gpt_extracted': 2, 'match': False}
# {'section': 'health_and_organ_function', 'key': 'tumor_tissue_lesion_availability', 'ground_truth': 'Yes', 'gpt_extracted': None, 'match': False}
#
# Mismatch Count by Section and Key:
# Section: demographics_and_general_characteristics
#   signed_consent: 6 mismatches
#   protocol_compliance: 13 mismatches
#   months_of_life_expectancy: 7 mismatches
#   minimum_age: 3 mismatches
#   maximum_age: 1 mismatches
#   no_concurrent_participation_in_other_clinical_trials: 4 mismatches
#   follow_up_agreement: 1 mismatches
# Section: disease_characteristics
#   confirmed_locally_recurrent_breast_cancer: 11 mismatches
#   confirmed_metastases_breast_cancer: 5 mismatches
#   confirmed_breast_cancer: 3 mismatches
#   progress_after_previous_treatment: 2 mismatches
#   her2_status: 1 mismatches
# Section: health_and_organ_function
#   tumor_tissue_lesion_availability: 13 mismatches
#   sufficient_heart_cardiovascular_function: 7 mismatches
#   no_brain_metastases: 9 mismatches
#   no_metastases: 1 mismatches
#   no_pregnancy_nursing: 1 mismatches
#   ecog_performance_status_upper_bound: 1 mismatches
#   no_central_nervous_system_metastases: 4 mismatches
#   sufficient_renal_function: 5 mismatches
#   sufficient_bone_marrow: 2 mismatches
#   sufficient_liver_function: 4 mismatches
#   ast_alt_upper_bound_uln: 3 mismatches
#   bilirubin_upper_bound_uln: 2 mismatches
#   peripheral_neuropathy_grade_upper_bound: 3 mismatches
#   sufficient_lung_function: 2 mismatches
#   hgb_level_lower_bound_10_9_l: 1 mismatches
#   lvef_lower_bound_percent: 1 mismatches
#   swallow_ability: 1 mismatches
#   no_positive_hiv_status: 1 mismatches
#   anc_level_lower_bound_10_9_l: 1 mismatches
